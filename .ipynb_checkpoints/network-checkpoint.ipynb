# %%
import os
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
import keras as k
import keras.layers as l
import random
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Get dataset

# %%
DIM = 100

# %%
dataset_1 = '/mnt/data/deepfake/datasets/faces/Actor_01/'
dataset_2 = '/mnt/data/deepfake/datasets/faces/Actor_02/'

# %%
def get_pics(path, lim = 1000): 
    pics = []
    for i,pic in enumerate(os.listdir(path)):
        gray = cv.cvtColor(cv.imread(path + pic), cv.COLOR_BGR2GRAY)
        pics.append(gray)
        
        if i == lim:break
    return pics

# %%
def resize_pics(pics):
    resize = []
    for pic in pics:
        resize.append(cv.resize(pic, (DIM, DIM)))
    return np.array(resize)

# %%
pics_a = get_pics(dataset_1)
pics_b = get_pics(dataset_2)

# %%
len(pics_b)
# Out:
# 1001

# %%
plt.figure(figsize=(20,6))
for i in range(1,5):
    plt.subplot(2, 4, i)
    i_pic = random.randint(0,len(pics_b))
    plt.imshow(pics_a[i_pic])
    
    plt.subplot(2,4,4+i)
    plt.imshow(pics_b[i_pic])
plt.show()

# %%
pics_a = resize_pics(pics_a)
pics_b = resize_pics(pics_b)

# %%
pics_a.shape, pics_b.shape
# Out:
# ((2002, 100, 100), (2002, 100, 100))

# %%
Xa = pics_a / 255.
Xb = pics_b / 255.

# %%
def mat2flat(pics):
    return pics.reshape((len(pics), DIM*DIM))
def flat2mat(pics):
    return pics.reshape((len(pics), DIM, DIM))

# %%
Xa = flat2mat(Xa)
Xb = flat2mat(Xb)

# %%
Xa.shape,Xb.shape
# Out:
# ((2002, 100, 100), (2002, 100, 100))

# %% [markdown]
# # Dense Network

# %%
train_xa, test_xa = Xa[0:int(len(Xa)*0.9)], Xa[int(len(Xa)*0.9):]
train_xb, test_xb = Xb[0:int(len(Xb)*0.9)], Xb[int(len(Xb)*0.9):]

# %%
input_layer = l.Input(shape = (DIM * DIM,))
encoded = l.Dense(32, activation='relu')(input_layer)
decoded_a = l.Dense(DIM*DIM, activation = "sigmoid")(encoded)
decoded_b = l.Dense(DIM*DIM, activation = "sigmoid")(encoded)
autoencodeur_a = k.Model(input_layer, decoded_a)
autoencodeur_b = k.Model(input_layer, decoded_b)
encodeur = k.Model(input_layer, encoded)


# create a placeholder for an encoded (32-dimensional) input
encoded_input = l.Input(shape=(32,))
# retrieve the last layer of the autoencoder model
decoder_a_layer = autoencodeur_a.layers[-1]
decoder_b_layer = autoencodeur_b.layers[-1]

# create the decoder model
decodeur_a = k.Model(encoded_input, decoder_a_layer(encoded_input))
decodeur_b = k.Model(encoded_input, decoder_b_layer(encoded_input))

# %%
autoencodeur_a.compile(optimizer='adadelta', loss='binary_crossentropy')
autoencodeur_b.compile(optimizer='adadelta', loss='binary_crossentropy')

# %%
for _ in range(50):
    autoencodeur_a.fit(train_xa, train_xa, epochs=1)
    autoencodeur_b.fit(train_xb, train_xb, epochs=1)
# Out:
# Epoch 1/1
# 1801/1801 [==============================] - 1s 496us/step - loss: 0.6765
# Epoch 1/1
# 1801/1801 [==============================] - 1s 463us/step - loss: 0.6037
# Epoch 1/1
# 1801/1801 [==============================] - 0s 271us/step - loss: 0.5821
# Epoch 1/1
# 1801/1801 [==============================] - 0s 256us/step - loss: 0.5552
# Epoch 1/1
# 1801/1801 [==============================] - 0s 253us/step - loss: 0.5774
# Epoch 1/1
# 1801/1801 [==============================] - 0s 256us/step - loss: 0.5544
# Epoch 1/1
# 1801/1801 [==============================] - 0s 260us/step - loss: 0.5772
# Epoch 1/1
# 1801/1801 [==============================] - 0s 273us/step - loss: 0.5540
# Epoch 1/1
# 1801/1801 [==============================] - 0s 255us/step - loss: 0.5771
# Epoch 1/1
# 1801/1801 [==============================] - 0s 264us/step - loss: 0.5539
# Epoch 1/1
# 1801/1801 [==============================] - 0s 276us/step - loss: 0.5771
# Epoch 1/1
# 1801/1801 [==============================] - 0s 241us/step - loss: 0.5537
# Epoch 1/1
# 1801/1801 [==============================] - 0s 269us/step - loss: 0.5770
# Epoch 1/1
# 1801/1801 [==============================] - 0s 252us/step - loss: 0.5535
# Epoch 1/1
# 1801/1801 [==============================] - 0s 260us/step - loss: 0.5769
# Epoch 1/1
# 1801/1801 [==============================] - 1s 284us/step - loss: 0.5534
# Epoch 1/1
# 1801/1801 [==============================] - 0s 270us/step - loss: 0.5767
# Epoch 1/1
# 1801/1801 [==============================] - 0s 259us/step - loss: 0.5532
# Epoch 1/1
# 1801/1801 [==============================] - 0s 271us/step - loss: 0.5765
# Epoch 1/1
# 1801/1801 [==============================] - 1s 279us/step - loss: 0.5531
# Epoch 1/1
# 1801/1801 [==============================] - 0s 265us/step - loss: 0.5762
# Epoch 1/1
# 1801/1801 [==============================] - 0s 261us/step - loss: 0.5529
# Epoch 1/1
# 1801/1801 [==============================] - 0s 266us/step - loss: 0.5757
# Epoch 1/1
# 1801/1801 [==============================] - 0s 256us/step - loss: 0.5527
# Epoch 1/1
# 1801/1801 [==============================] - 0s 254us/step - loss: 0.5749
# Epoch 1/1
# 1801/1801 [==============================] - 0s 268us/step - loss: 0.5524
# Epoch 1/1
# 1801/1801 [==============================] - 0s 276us/step - loss: 0.5739
# Epoch 1/1
# 1801/1801 [==============================] - 0s 249us/step - loss: 0.5520
# Epoch 1/1
# 1801/1801 [==============================] - 0s 258us/step - loss: 0.5725
# Epoch 1/1
# 1801/1801 [==============================] - 0s 267us/step - loss: 0.5515
# Epoch 1/1
# 1801/1801 [==============================] - 1s 279us/step - loss: 0.5707
# Epoch 1/1
# 1801/1801 [==============================] - 0s 270us/step - loss: 0.5510
# Epoch 1/1
# 1801/1801 [==============================] - 0s 249us/step - loss: 0.5689
# Epoch 1/1
# 1801/1801 [==============================] - 0s 253us/step - loss: 0.5504
# Epoch 1/1
# 1801/1801 [==============================] - 0s 259us/step - loss: 0.5671
# Epoch 1/1
# 1801/1801 [==============================] - 0s 273us/step - loss: 0.5496
# Epoch 1/1
# 1801/1801 [==============================] - 0s 264us/step - loss: 0.5654
# Epoch 1/1
# 1801/1801 [==============================] - 0s 260us/step - loss: 0.5489
# Epoch 1/1
# 1801/1801 [==============================] - 0s 247us/step - loss: 0.5642
# Epoch 1/1
# 1801/1801 [==============================] - 1s 278us/step - loss: 0.5481
# Epoch 1/1
# 1801/1801 [==============================] - 0s 265us/step - loss: 0.5632
# Epoch 1/1
# 1801/1801 [==============================] - 0s 271us/step - loss: 0.5474
# Epoch 1/1
# 1801/1801 [==============================] - 0s 268us/step - loss: 0.5625
# Epoch 1/1
# 1801/1801 [==============================] - 0s 258us/step - loss: 0.5467
# Epoch 1/1
# 1801/1801 [==============================] - 0s 266us/step - loss: 0.5620
# Epoch 1/1
# 1801/1801 [==============================] - 0s 266us/step - loss: 0.5461
# Epoch 1/1
# 1801/1801 [==============================] - 0s 273us/step - loss: 0.5615
# Epoch 1/1
# 1801/1801 [==============================] - 0s 270us/step - loss: 0.5457
# Epoch 1/1
# 1801/1801 [==============================] - 0s 234us/step - loss: 0.5612
# Epoch 1/1
# 1801/1801 [==============================] - 1s 282us/step - loss: 0.5452
# Epoch 1/1
# 1801/1801 [==============================] - 0s 264us/step - loss: 0.5609
# Epoch 1/1
# 1801/1801 [==============================] - 0s 252us/step - loss: 0.5448
# Epoch 1/1
# 1801/1801 [==============================] - 0s 258us/step - loss: 0.5607
# Epoch 1/1
# 1801/1801 [==============================] - 0s 241us/step - loss: 0.5444
# Epoch 1/1
# 1801/1801 [==============================] - 0s 247us/step - loss: 0.5604
# Epoch 1/1
# 1801/1801 [==============================] - 1s 281us/step - loss: 0.5441
# Epoch 1/1
# 1801/1801 [==============================] - 0s 238us/step - loss: 0.5601
# Epoch 1/1
# 1801/1801 [==============================] - 0s 247us/step - loss: 0.5438
# Epoch 1/1
# 1801/1801 [==============================] - 0s 262us/step - loss: 0.5598
# Epoch 1/1
# 1801/1801 [==============================] - 0s 265us/step - loss: 0.5435
# Epoch 1/1
# 1801/1801 [==============================] - 1s 279us/step - loss: 0.5595
# Epoch 1/1
# 1801/1801 [==============================] - 0s 265us/step - loss: 0.5432
# Epoch 1/1
# 1801/1801 [==============================] - 1s 281us/step - loss: 0.5591
# Epoch 1/1
# 1801/1801 [==============================] - 0s 264us/step - loss: 0.5429
# Epoch 1/1
# 1801/1801 [==============================] - 0s 252us/step - loss: 0.5588
# Epoch 1/1
# 1801/1801 [==============================] - 0s 251us/step - loss: 0.5425
# Epoch 1/1
# 1801/1801 [==============================] - 0s 276us/step - loss: 0.5583
# Epoch 1/1
# 1801/1801 [==============================] - 0s 259us/step - loss: 0.5422
# Epoch 1/1
# 1801/1801 [==============================] - 0s 245us/step - loss: 0.5579
# Epoch 1/1
# 1801/1801 [==============================] - 0s 246us/step - loss: 0.5418
# Epoch 1/1
# 1801/1801 [==============================] - 0s 269us/step - loss: 0.5574
# Epoch 1/1
# 1801/1801 [==============================] - 0s 271us/step - loss: 0.5415
# Epoch 1/1
# 1801/1801 [==============================] - 0s 270us/step - loss: 0.5569
# Epoch 1/1
# 1801/1801 [==============================] - 0s 273us/step - loss: 0.5411
# Epoch 1/1
# 1801/1801 [==============================] - 0s 260us/step - loss: 0.5564
# Epoch 1/1
# 1801/1801 [==============================] - 1s 294us/step - loss: 0.5407
# Epoch 1/1
# 1801/1801 [==============================] - 0s 265us/step - loss: 0.5558
# Epoch 1/1
# 1801/1801 [==============================] - 0s 267us/step - loss: 0.5404
# Epoch 1/1
# 1801/1801 [==============================] - 0s 259us/step - loss: 0.5552
# Epoch 1/1
# 1801/1801 [==============================] - 0s 265us/step - loss: 0.5400
# Epoch 1/1
# 1801/1801 [==============================] - 0s 265us/step - loss: 0.5547
# Epoch 1/1
# 1801/1801 [==============================] - 1s 287us/step - loss: 0.5396
# Epoch 1/1
# 1801/1801 [==============================] - 0s 272us/step - loss: 0.5541
# Epoch 1/1
# 1801/1801 [==============================] - 0s 271us/step - loss: 0.5393
# Epoch 1/1
# 1801/1801 [==============================] - 1s 287us/step - loss: 0.5536
# Epoch 1/1
# 1801/1801 [==============================] - 0s 248us/step - loss: 0.5390
# Epoch 1/1
# 1801/1801 [==============================] - 0s 252us/step - loss: 0.5530
# Epoch 1/1
# 1801/1801 [==============================] - 0s 251us/step - loss: 0.5387
# Epoch 1/1
# 1801/1801 [==============================] - 0s 256us/step - loss: 0.5525
# Epoch 1/1
# 1801/1801 [==============================] - 0s 265us/step - loss: 0.5385
# Epoch 1/1
# 1801/1801 [==============================] - 0s 267us/step - loss: 0.5521
# Epoch 1/1
# 1801/1801 [==============================] - 0s 266us/step - loss: 0.5383
# Epoch 1/1
# 1801/1801 [==============================] - 0s 257us/step - loss: 0.5516
# Epoch 1/1
# 1801/1801 [==============================] - 0s 270us/step - loss: 0.5380
# Epoch 1/1
# 1801/1801 [==============================] - 0s 250us/step - loss: 0.5512
# Epoch 1/1
# 1801/1801 [==============================] - 0s 272us/step - loss: 0.5379
# Epoch 1/1
# 1801/1801 [==============================] - 0s 259us/step - loss: 0.5508
# Epoch 1/1
# 1801/1801 [==============================] - 0s 260us/step - loss: 0.5377
# Epoch 1/1
# 1801/1801 [==============================] - 0s 264us/step - loss: 0.5504
# Epoch 1/1
# 1801/1801 [==============================] - 0s 259us/step - loss: 0.5376

# %%
1+1

# %%
test_img = test_xa[50]

# %%
plt.subplot(1,2,1)
plt.imshow(test_img.reshape(100,100))
plt.subplot(1,2,2)
pred = decodeur_b.predict(encodeur.predict(np.array([test_img])))
plt.imshow(pred[0].reshape(100,100))

# %%
plt.subplot(1,2,1)
plt.imshow(test_img.reshape(100,100))
plt.subplot(1,2,2)
pred = decodeur_b.predict(encodeur.predict(np.array([test_img])))
plt.imshow(pred[0].reshape(100,100))

# %%
plt.subplot(1,2,1)
plt.imshow(test_img.reshape(100,100))
plt.subplot(1,2,2)
pred = autoencodeur_b.predict(np.array([test_img]))
plt.imshow(pred[0].reshape(100,100))

# %%
plt.figure(figsize=(20,5))
for i in range(1,6):
    plt.subplot(2, 5, i)
    i_pic = random.randint(0,len(test_xb))
    plt.imshow(test_xb[i_pic].reshape((100,100)))
    
    plt.subplot(2,5, i+5)
    pred = autoencodeur_b.predict(np.array([test_xb[i_pic]]))
    plt.imshow(pred.reshape((100,100)))
    
plt.show()

# %%
1+1

# %% [markdown]
# # CNN

# %%
input_img = l.Input(shape=(100, 100, 1))  # adapt this if using `channels_first` image data format

x = l.Conv2D(16, (3, 3), activation='relu', padding='same')(input_img)
x = l.MaxPooling2D((2, 2), padding='same')(x)
x = l.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = l.MaxPooling2D((2, 2), padding='same')(x)
x = l.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
encoded = l.MaxPooling2D((2, 2), padding='same')(x)

# at this point the representation is (4, 4, 8) i.e. 128-dimensional

xa = l.Conv2D(8, (3, 3), activation='relu', padding='same')(encoded)
xa = l.UpSampling2D((2, 2))(xa)
xa = l.Conv2D(8, (3, 3), activation='relu', padding='same')(xa)
xa = l.UpSampling2D((2, 2))(xa)
xa = l.Conv2D(16, (3, 3), activation='relu')(xa)
xa = l.UpSampling2D((2, 2))(xa)
decoded_a = l.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(xa)

xb = l.Conv2D(8, (3, 3), activation='relu', padding='same')(encoded)
xb = l.UpSampling2D((2, 2))(xb)
xb = l.Conv2D(8, (3, 3), activation='relu', padding='same')(xb)
xb = l.UpSampling2D((2, 2))(xb)
xb = l.Conv2D(16, (3, 3), activation='relu')(xb)
xb = l.UpSampling2D((2, 2))(xb)
decoded_b = l.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(xb)

autoencoder_a = k.Model(input_img, decoded_a)
autoencoder_b = k.Model(input_img, decoded_b)

encoder = k.Model(input_img, encoded)

autoencoder_a.compile(optimizer='adadelta', loss='binary_crossentropy')
autoencoder_b.compile(optimizer='adadelta', loss='binary_crossentropy')

# %%
decoder_a = k.Sequential()

for layer in autoencoder_a.layers[7:]:
    decoder_a.add(layer)
    
decoder_b = k.Sequential()

for layer in autoencoder_b.layers[7:]:
    decoder_b.add(layer)

# %%
autoencoder_a.fit(t, t)
# Out:
# Epoch 1/1
# 1801/1801 [==============================] - 5s 3ms/step - loss: 0.6609

# %%
train_xa = train_xa.reshape((len(train_xa), 100,100,1))
train_xb = train_xb.reshape((len(train_xb), 100,100,1))
test_xa = test_xa.reshape((len(test_xa), 100,100,1))
test_xb = test_xb.reshape((len(test_xb), 100,100,1))

# %%
t.shape
# Out:
# (1801, 100, 100, 1)

# %%
for _ in range(100):
    autoencoder_a.fit(train_xa, train_xa, epochs=1)
    autoencoder_b.fit(train_xb, train_xb, epochs=1)
# Out:
# Epoch 1/1
# 1801/1801 [==============================] - 3s 1ms/step - loss: 0.6384
# Epoch 1/1
# 1801/1801 [==============================] - 3s 1ms/step - loss: 0.6228
# Epoch 1/1
# 1801/1801 [==============================] - 1s 818us/step - loss: 0.5870
# Epoch 1/1
# 1801/1801 [==============================] - 1s 812us/step - loss: 0.5700
# Epoch 1/1
# 1801/1801 [==============================] - 1s 816us/step - loss: 0.5667
# Epoch 1/1
# 1801/1801 [==============================] - 1s 814us/step - loss: 0.5532
# Epoch 1/1
# 1801/1801 [==============================] - 1s 812us/step - loss: 0.5574
# Epoch 1/1
# 1801/1801 [==============================] - 1s 813us/step - loss: 0.5473
# Epoch 1/1
# 1801/1801 [==============================] - 1s 814us/step - loss: 0.5529
# Epoch 1/1
# 1801/1801 [==============================] - 1s 804us/step - loss: 0.5447
# Epoch 1/1
# 1801/1801 [==============================] - 1s 815us/step - loss: 0.5500
# Epoch 1/1
# 1801/1801 [==============================] - 1s 813us/step - loss: 0.5433
# Epoch 1/1
# 1801/1801 [==============================] - 1s 810us/step - loss: 0.5474
# Epoch 1/1
# 1801/1801 [==============================] - 1s 813us/step - loss: 0.5422
# Epoch 1/1
# 1801/1801 [==============================] - 1s 815us/step - loss: 0.5457
# Epoch 1/1
# 1801/1801 [==============================] - 1s 812us/step - loss: 0.5412
# Epoch 1/1
# 1801/1801 [==============================] - 1s 819us/step - loss: 0.5442
# Epoch 1/1
# 1801/1801 [==============================] - 1s 812us/step - loss: 0.5405
# Epoch 1/1
# 1801/1801 [==============================] - 1s 815us/step - loss: 0.5426
# Epoch 1/1
# 1801/1801 [==============================] - 1s 813us/step - loss: 0.5395
# Epoch 1/1
# 1801/1801 [==============================] - 1s 814us/step - loss: 0.5422
# Epoch 1/1
# 1801/1801 [==============================] - 1s 813us/step - loss: 0.5394
# Epoch 1/1
# 1801/1801 [==============================] - 1s 816us/step - loss: 0.5417
# Epoch 1/1
# 1801/1801 [==============================] - 1s 811us/step - loss: 0.5386
# Epoch 1/1
# 1801/1801 [==============================] - 1s 813us/step - loss: 0.5409
# Epoch 1/1
# 1801/1801 [==============================] - 1s 812us/step - loss: 0.5383
# Epoch 1/1
# 1801/1801 [==============================] - 1s 820us/step - loss: 0.5408
# Epoch 1/1
# 1801/1801 [==============================] - 1s 813us/step - loss: 0.5374
# Epoch 1/1
# 1801/1801 [==============================] - 1s 814us/step - loss: 0.5401
# Epoch 1/1
# 1801/1801 [==============================] - 1s 809us/step - loss: 0.5372
# Epoch 1/1
# 1801/1801 [==============================] - 1s 813us/step - loss: 0.5396
# Epoch 1/1
# 1801/1801 [==============================] - 1s 813us/step - loss: 0.5369
# Epoch 1/1
# 1801/1801 [==============================] - 1s 816us/step - loss: 0.5391
# Epoch 1/1
# 1801/1801 [==============================] - 1s 812us/step - loss: 0.5364
# Epoch 1/1
# 1801/1801 [==============================] - 1s 815us/step - loss: 0.5385
# Epoch 1/1
# 1801/1801 [==============================] - 1s 812us/step - loss: 0.5365
# Epoch 1/1
# 1801/1801 [==============================] - 1s 814us/step - loss: 0.5383
# Epoch 1/1
# 1801/1801 [==============================] - 1s 812us/step - loss: 0.5360
# Epoch 1/1
# 1801/1801 [==============================] - 1s 812us/step - loss: 0.5384
# Epoch 1/1
# 1801/1801 [==============================] - 1s 808us/step - loss: 0.5359
# Epoch 1/1
# 1801/1801 [==============================] - 1s 815us/step - loss: 0.5379
# Epoch 1/1
# 1801/1801 [==============================] - 1s 811us/step - loss: 0.5356
# Epoch 1/1
# 1801/1801 [==============================] - 1s 820us/step - loss: 0.5372
# Epoch 1/1
# 1801/1801 [==============================] - 1s 812us/step - loss: 0.5354
# Epoch 1/1
# 1801/1801 [==============================] - 1s 822us/step - loss: 0.5374
# Epoch 1/1
# 1801/1801 [==============================] - 1s 810us/step - loss: 0.5354
# Epoch 1/1
# 1801/1801 [==============================] - 1s 813us/step - loss: 0.5372
# Epoch 1/1
# 1801/1801 [==============================] - 1s 813us/step - loss: 0.5349
# Epoch 1/1
# 1801/1801 [==============================] - 1s 811us/step - loss: 0.5370
# Epoch 1/1
# 1801/1801 [==============================] - 1s 814us/step - loss: 0.5351
# Epoch 1/1
# 1801/1801 [==============================] - 1s 805us/step - loss: 0.5368
# Epoch 1/1
# 1801/1801 [==============================] - 1s 813us/step - loss: 0.5349
# Epoch 1/1
# 1801/1801 [==============================] - 1s 814us/step - loss: 0.5366
# Epoch 1/1
# 1801/1801 [==============================] - 1s 808us/step - loss: 0.5345
# Epoch 1/1
# 1801/1801 [==============================] - 1s 807us/step - loss: 0.5365
# Epoch 1/1
# 1801/1801 [==============================] - 1s 810us/step - loss: 0.5348
# Epoch 1/1
# 1801/1801 [==============================] - 1s 811us/step - loss: 0.5357
# Epoch 1/1
# 1801/1801 [==============================] - 1s 811us/step - loss: 0.5345
# Epoch 1/1
# 1801/1801 [==============================] - 1s 815us/step - loss: 0.5361
# Epoch 1/1
# 1801/1801 [==============================] - 1s 809us/step - loss: 0.5343
# Epoch 1/1
# 1801/1801 [==============================] - 1s 814us/step - loss: 0.5359
# Epoch 1/1
# 1801/1801 [==============================] - 1s 811us/step - loss: 0.5342
# Epoch 1/1
# 1801/1801 [==============================] - 1s 812us/step - loss: 0.5357
# Epoch 1/1
# 1801/1801 [==============================] - 1s 809us/step - loss: 0.5338
# Epoch 1/1
# 1801/1801 [==============================] - 1s 813us/step - loss: 0.5355
# Epoch 1/1
# 1801/1801 [==============================] - 1s 812us/step - loss: 0.5337
# Epoch 1/1
# 1801/1801 [==============================] - 1s 811us/step - loss: 0.5354
# Epoch 1/1
# 1801/1801 [==============================] - 1s 808us/step - loss: 0.5339
# Epoch 1/1
# 1801/1801 [==============================] - 1s 816us/step - loss: 0.5351
# Epoch 1/1
# 1801/1801 [==============================] - 1s 809us/step - loss: 0.5338
# Epoch 1/1
# 1801/1801 [==============================] - 1s 812us/step - loss: 0.5353
# Epoch 1/1
# 1801/1801 [==============================] - 1s 809us/step - loss: 0.5336
# Epoch 1/1
# 1801/1801 [==============================] - 1s 813us/step - loss: 0.5352
# Epoch 1/1
# 1801/1801 [==============================] - 1s 806us/step - loss: 0.5335
# Epoch 1/1
# 1801/1801 [==============================] - 1s 814us/step - loss: 0.5351
# Epoch 1/1
# 1801/1801 [==============================] - 1s 811us/step - loss: 0.5333
# Epoch 1/1
# 1801/1801 [==============================] - 1s 815us/step - loss: 0.5349
# Epoch 1/1
# 1801/1801 [==============================] - 1s 811us/step - loss: 0.5335
# Epoch 1/1
# 1801/1801 [==============================] - 1s 807us/step - loss: 0.5348
# Epoch 1/1
# 1801/1801 [==============================] - 1s 817us/step - loss: 0.5334
# Epoch 1/1
# 1801/1801 [==============================] - 1s 809us/step - loss: 0.5345
# Epoch 1/1
# 1801/1801 [==============================] - 1s 813us/step - loss: 0.5332
# Epoch 1/1
# 1801/1801 [==============================] - 1s 819us/step - loss: 0.5344
# Epoch 1/1
# 1801/1801 [==============================] - 1s 810us/step - loss: 0.5332
# Epoch 1/1
# 1801/1801 [==============================] - 1s 812us/step - loss: 0.5345
# Epoch 1/1
# 1801/1801 [==============================] - 1s 809us/step - loss: 0.5332
# Epoch 1/1
# 1801/1801 [==============================] - 1s 810us/step - loss: 0.5344
# Epoch 1/1
# 1801/1801 [==============================] - 1s 811us/step - loss: 0.5331
# Epoch 1/1
# 1801/1801 [==============================] - 1s 809us/step - loss: 0.5342
# Epoch 1/1
# 1801/1801 [==============================] - 1s 814us/step - loss: 0.5331
# Epoch 1/1
# 1801/1801 [==============================] - 1s 809us/step - loss: 0.5342
# Epoch 1/1
# 1801/1801 [==============================] - 1s 802us/step - loss: 0.5331
# Epoch 1/1
# 1801/1801 [==============================] - 1s 821us/step - loss: 0.5340
# Epoch 1/1
# 1801/1801 [==============================] - 1s 813us/step - loss: 0.5330
# Epoch 1/1
# 1801/1801 [==============================] - 1s 808us/step - loss: 0.5338
# Epoch 1/1
# 1801/1801 [==============================] - 1s 809us/step - loss: 0.5329
# Epoch 1/1
# 1801/1801 [==============================] - 1s 811us/step - loss: 0.5340
# Epoch 1/1
# 1801/1801 [==============================] - 1s 813us/step - loss: 0.5329
# Epoch 1/1
# 1801/1801 [==============================] - 1s 811us/step - loss: 0.5337
# Epoch 1/1
# 1801/1801 [==============================] - 1s 810us/step - loss: 0.5327
# Epoch 1/1
# 1801/1801 [==============================] - 1s 814us/step - loss: 0.5338
# Epoch 1/1
# 1801/1801 [==============================] - 1s 807us/step - loss: 0.5327
# Epoch 1/1
# 1801/1801 [==============================] - 1s 811us/step - loss: 0.5338
# Epoch 1/1
# 1801/1801 [==============================] - 1s 808us/step - loss: 0.5326
# Epoch 1/1
# 1801/1801 [==============================] - 1s 818us/step - loss: 0.5337
# Epoch 1/1
# 1801/1801 [==============================] - 1s 811us/step - loss: 0.5326
# Epoch 1/1
# 1801/1801 [==============================] - 1s 815us/step - loss: 0.5335
# Epoch 1/1
# 1801/1801 [==============================] - 1s 808us/step - loss: 0.5325
# Epoch 1/1
# 1801/1801 [==============================] - 1s 813us/step - loss: 0.5334
# Epoch 1/1
# 1801/1801 [==============================] - 1s 811us/step - loss: 0.5323
# Epoch 1/1
# 1801/1801 [==============================] - 1s 812us/step - loss: 0.5334
# Epoch 1/1
# 1801/1801 [==============================] - 1s 807us/step - loss: 0.5322
# Epoch 1/1
# 1801/1801 [==============================] - 1s 812us/step - loss: 0.5331
# Epoch 1/1
# 1801/1801 [==============================] - 1s 814us/step - loss: 0.5321
# Epoch 1/1
# 1801/1801 [==============================] - 1s 819us/step - loss: 0.5332
# Epoch 1/1
# 1801/1801 [==============================] - 1s 815us/step - loss: 0.5323
# Epoch 1/1
# 1801/1801 [==============================] - 1s 818us/step - loss: 0.5330
# Epoch 1/1
# 1801/1801 [==============================] - 1s 813us/step - loss: 0.5323
# Epoch 1/1
# 1801/1801 [==============================] - 1s 814us/step - loss: 0.5331
# Epoch 1/1
# 1801/1801 [==============================] - 1s 813us/step - loss: 0.5320
# Epoch 1/1
# 1801/1801 [==============================] - 1s 813us/step - loss: 0.5332
# Epoch 1/1
# 1801/1801 [==============================] - 1s 811us/step - loss: 0.5322
# Epoch 1/1
# 1801/1801 [==============================] - 1s 816us/step - loss: 0.5331
# Epoch 1/1
# 1801/1801 [==============================] - 1s 810us/step - loss: 0.5320
# Epoch 1/1
# 1801/1801 [==============================] - 1s 814us/step - loss: 0.5330
# Epoch 1/1
# 1801/1801 [==============================] - 1s 815us/step - loss: 0.5319
# Epoch 1/1
# 1801/1801 [==============================] - 1s 818us/step - loss: 0.5330
# Epoch 1/1
# 1801/1801 [==============================] - 1s 812us/step - loss: 0.5319
# Epoch 1/1
# 1801/1801 [==============================] - 1s 815us/step - loss: 0.5328
# Epoch 1/1
# 1801/1801 [==============================] - 1s 814us/step - loss: 0.5320
# Epoch 1/1
# 1801/1801 [==============================] - 1s 811us/step - loss: 0.5327
# Epoch 1/1
# 1801/1801 [==============================] - 1s 809us/step - loss: 0.5319
# Epoch 1/1
# 1801/1801 [==============================] - 1s 805us/step - loss: 0.5326
# Epoch 1/1
# 1801/1801 [==============================] - 1s 810us/step - loss: 0.5318
# Epoch 1/1
# 1801/1801 [==============================] - 1s 813us/step - loss: 0.5328
# Epoch 1/1
# 1801/1801 [==============================] - 1s 809us/step - loss: 0.5318
# Epoch 1/1
# 1801/1801 [==============================] - 1s 810us/step - loss: 0.5324
# Epoch 1/1
# 1801/1801 [==============================] - 1s 813us/step - loss: 0.5318
# Epoch 1/1
# 1801/1801 [==============================] - 1s 814us/step - loss: 0.5327
# Epoch 1/1
# 1801/1801 [==============================] - 1s 816us/step - loss: 0.5317
# Epoch 1/1
# 1801/1801 [==============================] - 1s 815us/step - loss: 0.5325
# Epoch 1/1
# 1801/1801 [==============================] - 1s 813us/step - loss: 0.5317
# Epoch 1/1
# 1801/1801 [==============================] - 1s 823us/step - loss: 0.5324
# Epoch 1/1
# 1801/1801 [==============================] - 1s 822us/step - loss: 0.5317
# Epoch 1/1
# 1801/1801 [==============================] - 1s 825us/step - loss: 0.5324
# Epoch 1/1
# 1801/1801 [==============================] - 1s 813us/step - loss: 0.5317
# Epoch 1/1
# 1801/1801 [==============================] - 1s 814us/step - loss: 0.5322
# Epoch 1/1
# 1801/1801 [==============================] - 1s 812us/step - loss: 0.5315
# Epoch 1/1
# 1801/1801 [==============================] - 1s 815us/step - loss: 0.5323
# Epoch 1/1
# 1801/1801 [==============================] - 1s 812us/step - loss: 0.5316
# Epoch 1/1
# 1801/1801 [==============================] - 1s 817us/step - loss: 0.5324
# Epoch 1/1
# 1801/1801 [==============================] - 1s 809us/step - loss: 0.5316
# Epoch 1/1
# 1801/1801 [==============================] - 1s 814us/step - loss: 0.5324
# Epoch 1/1
# 1801/1801 [==============================] - 1s 804us/step - loss: 0.5315
# Epoch 1/1
# 1801/1801 [==============================] - 1s 813us/step - loss: 0.5322
# Epoch 1/1
# 1801/1801 [==============================] - 1s 808us/step - loss: 0.5313
# Epoch 1/1
# 1801/1801 [==============================] - 1s 810us/step - loss: 0.5321
# Epoch 1/1
# 1801/1801 [==============================] - 1s 812us/step - loss: 0.5314
# Epoch 1/1
# 1801/1801 [==============================] - 1s 815us/step - loss: 0.5322
# Epoch 1/1
# 1801/1801 [==============================] - 1s 810us/step - loss: 0.5316
# Epoch 1/1
# 1801/1801 [==============================] - 1s 813us/step - loss: 0.5321
# Epoch 1/1
# 1801/1801 [==============================] - 1s 810us/step - loss: 0.5315
# Epoch 1/1
# 1801/1801 [==============================] - 1s 815us/step - loss: 0.5321
# Epoch 1/1
# 1801/1801 [==============================] - 1s 810us/step - loss: 0.5311
# Epoch 1/1
# 1801/1801 [==============================] - 1s 816us/step - loss: 0.5318
# Epoch 1/1
# 1801/1801 [==============================] - 1s 804us/step - loss: 0.5314
# Epoch 1/1
# 1801/1801 [==============================] - 1s 811us/step - loss: 0.5320
# Epoch 1/1
# 1801/1801 [==============================] - 1s 809us/step - loss: 0.5313
# Epoch 1/1
# 1801/1801 [==============================] - 1s 817us/step - loss: 0.5320
# Epoch 1/1
# 1801/1801 [==============================] - 1s 809us/step - loss: 0.5312
# Epoch 1/1
# 1801/1801 [==============================] - 1s 815us/step - loss: 0.5320
# Epoch 1/1
# 1801/1801 [==============================] - 1s 809us/step - loss: 0.5313
# Epoch 1/1
# 1801/1801 [==============================] - 1s 814us/step - loss: 0.5319
# Epoch 1/1
# 1801/1801 [==============================] - 1s 811us/step - loss: 0.5311
# Epoch 1/1
# 1801/1801 [==============================] - 1s 817us/step - loss: 0.5319
# Epoch 1/1
# 1801/1801 [==============================] - 1s 807us/step - loss: 0.5312
# Epoch 1/1
# 1801/1801 [==============================] - 1s 806us/step - loss: 0.5316
# Epoch 1/1
# 1801/1801 [==============================] - 1s 809us/step - loss: 0.5312
# Epoch 1/1
# 1801/1801 [==============================] - 1s 815us/step - loss: 0.5317
# Epoch 1/1
# 1801/1801 [==============================] - 1s 813us/step - loss: 0.5312
# Epoch 1/1
# 1801/1801 [==============================] - 1s 819us/step - loss: 0.5313
# Epoch 1/1
# 1801/1801 [==============================] - 1s 808us/step - loss: 0.5312
# Epoch 1/1
# 1801/1801 [==============================] - 1s 813us/step - loss: 0.5317
# Epoch 1/1
# 1801/1801 [==============================] - 1s 816us/step - loss: 0.5310
# Epoch 1/1
# 1801/1801 [==============================] - 1s 828us/step - loss: 0.5318
# Epoch 1/1
# 1801/1801 [==============================] - 1s 817us/step - loss: 0.5310
# Epoch 1/1
# 1801/1801 [==============================] - 1s 825us/step - loss: 0.5316
# Epoch 1/1
# 1801/1801 [==============================] - 1s 817us/step - loss: 0.5310
# Epoch 1/1
# 1801/1801 [==============================] - 1s 820us/step - loss: 0.5316
# Epoch 1/1
# 1801/1801 [==============================] - 1s 821us/step - loss: 0.5311
# Epoch 1/1
# 1801/1801 [==============================] - 1s 821us/step - loss: 0.5316
# Epoch 1/1
# 1801/1801 [==============================] - 1s 811us/step - loss: 0.5310
# Epoch 1/1
# 1801/1801 [==============================] - 1s 816us/step - loss: 0.5316
# Epoch 1/1
# 1801/1801 [==============================] - 1s 811us/step - loss: 0.5311
# Epoch 1/1
# 1801/1801 [==============================] - 1s 815us/step - loss: 0.5316
# Epoch 1/1
# 1801/1801 [==============================] - 1s 812us/step - loss: 0.5310
# Epoch 1/1
# 1801/1801 [==============================] - 1s 813us/step - loss: 0.5312
# Epoch 1/1
# 1801/1801 [==============================] - 1s 807us/step - loss: 0.5309
# Epoch 1/1
# 1801/1801 [==============================] - 1s 819us/step - loss: 0.5313
# Epoch 1/1
# 1801/1801 [==============================] - 1s 814us/step - loss: 0.5311

# %%
test

# %%
plt.imshow(train_xb[0].reshape((100,100)))

# %%
plt.imshow(test_img.reshape((100,100)))

# %%
code = encoder.predict(test_img.reshape(1,100,100,1))

# %%
plt.imshow(decoder_a.predict(code).reshape(100,100))

# %%
plt.imshow(autoencoder_a.predict(test_img.reshape(1,100,100,1)).reshape(100,100))

# %%
plt.figure(figsize=(20,5))
for i in range(1,6):
    plt.subplot(2, 5, i)
    i_pic = random.randint(0,len(test_xb))
    plt.imshow(test_xb[i_pic].reshape((100,100)))
    
    plt.subplot(2,5, i+5)
    pred = autoencoder_a.predict(np.array([test_xb[i_pic]]))
    plt.imshow(pred.reshape((100,100)))
    
plt.show()

# %%
plt.figure(figsize=(20,5))
for i in range(1,6):
    i_pic = random.randint(0,len(test_xa))
    test_img = test_xb[i_pic]
    
    plt.subplot(2, 5, i)
    plt.imshow(test_img.reshape((100,100)))
    
    plt.subplot(2,5, i+5)
    pred = autoencoder_a.predict(np.array([test_img]))
    plt.imshow(pred.reshape((100,100)))
    
plt.show()

# %%
plt.figure(figsize=(20,5))
for i in range(1,6):
    i_pic = random.randint(0,len(test_xa))
    test_img = test_xa[i_pic]
    
    plt.subplot(2, 5, i)
    plt.imshow(test_img.reshape((100,100)))
    
    plt.subplot(2,5, i+5)
    pred = autoencoder_a.predict(np.array([test_img]))
    plt.imshow(pred.reshape((100,100)))
    
plt.show()

# %%
plt.figure(figsize=(20,5))
for i in range(1,6):
    plt.subplot(2, 5, i)
    i_pic = random.randint(0,len(test_xa))
    plt.imshow(test_xa[i_pic].reshape((100,100)))
    
    plt.subplot(2,5, i+5)
    pred = decoder_b.predict(encoder.predict(np.array([test_xa[i_pic]])))
    plt.imshow(pred.reshape((100,100)))
    
plt.show()
